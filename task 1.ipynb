# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
from  warnings import filterwarnings
filterwarnings('ignore')

# %%
dff=pd.read_csv(r"C:\Users\saura\Downloads\titanic\train.csv")
dff
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
dff.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
dff.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
dff.drop(["Cabin","Age"],axis=1,inplace=True)
dff
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
dff.select_dtypes(include=np.number).columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
dff["Embarked"]=dff["Embarked"].fillna(dff["Embarked"].mode()[0])

# %%
((dff.isna().sum()/dff.shape[0])*100).round(3)
# Out:
# PassengerId    0.0
# Survived       0.0
# Pclass         0.0
# Name           0.0
# Sex            0.0
# SibSp          0.0
# Parch          0.0
# Ticket         0.0
# Fare           0.0
# Embarked       0.0
# dtype: float64

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
df_num=df.select_dtypes(exclude=object)
df_cat=df.select_dtypes(include=object)

# %%
num_vars=df_num

nrows=2
ncols=2
repeater=1

plt.figure(figsize=(18,7))

for i in num_vars:
    plt.subplot(nrows,ncols,repeater)
    repeater+=1
    plt.title(i)
    sns.distplot(dff[i])
                 
plt.tight_layout()
plt.show()

# %%
sns.barplot(x=dff["Sex"],y=dff["Survived"],data=dff)
print("Percentage of male who survived",dff["Survived"][dff["Sex"]=='male'].value_counts(normalize=True)[1]*100)
print("Percentage of female who survived",dff["Survived"][dff["Sex"]=='female'].value_counts(normalize=True)[1]*100)
# Out:
# Percentage of male who survived 18.890814558058924
# Percentage of female who survived 74.20382165605095

# %%
sns.barplot(x=dff["Parch"],y=dff["Survived"],data=dff)
print("Percentage of who survived having parch value 1=",dff["Survived"][dff["Parch"]==1].value_counts(normalize=True)[1]*100)
print("Percentage who survived having parch value 2=",dff["Survived"][dff["Parch"]==2].value_counts(normalize=True)[1]*100)
print("Percentage of who survived having parch value 3=",dff["Survived"][dff["Parch"]==3].value_counts(normalize=True)[1]*100)

print("Percentage of who survived having parch value 5=",dff["Survived"][dff["Parch"]==5].value_counts(normalize=True)[1]*100)
# Out:
# Percentage of who survived having parch value 1= 55.08474576271186
# Percentage who survived having parch value 2= 50.0
# Percentage of who survived having parch value 3= 60.0
# Percentage of who survived having parch value 5= 20.0

# %%
sns.barplot(x=dff["Pclass"],y=dff["Pclass"],data=dff)
print("Person who survived having 1st pclass value:",dff["Survived"][dff["Pclass"]==1].value_counts(normalize=True)[1]*100)
print("Person who survived having 2nd pclass value:",dff["Survived"][dff["Pclass"]==2].value_counts(normalize=True)[1]*100)
print("Person who survived having 3rd pclass value:",dff["Survived"][dff["Pclass"]==3].value_counts(normalize=True)[1]*100)
# Out:
# Person who survived having 1st pclass value: 62.96296296296296
# Person who survived having 2nd pclass value: 47.28260869565217
# Person who survived having 3rd pclass value: 24.236252545824847

# %%
sns.barplot(x=dff["Embarked"],y=dff["Survived"],data=dff)
# Out:
# <Axes: xlabel='Embarked', ylabel='Survived'>

# %%
sns.distplot(df_num)
# Out:
# <Axes: ylabel='Density'>

# %%
sns.scatterplot(dff)
# Out:
# <Axes: >
